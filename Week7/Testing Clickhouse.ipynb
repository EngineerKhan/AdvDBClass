# %%
# !pip install clickhouse-connect
# Out:
# Requirement already satisfied: clickhouse-connect in /opt/anaconda3/envs/RAGSystems/lib/python3.12/site-packages (0.9.2)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/RAGSystems/lib/python3.12/site-packages (from clickhouse-connect) (2025.10.5)
# Requirement already satisfied: urllib3>=1.26 in /opt/anaconda3/envs/RAGSystems/lib/python3.12/site-packages (from clickhouse-connect) (2.5.0)
# Requirement already satisfied: pytz in /opt/anaconda3/envs/RAGSystems/lib/python3.12/site-packages (from clickhouse-connect) (2025.2)
# Requirement already satisfied: zstandard in /opt/anaconda3/envs/RAGSystems/lib/python3.12/site-packages (from clickhouse-connect) (0.23.0)
# Requirement already satisfied: lz4 in /opt/anaconda3/envs/RAGSystems/lib/python3.12/site-packages (from clickhouse-connect) (4.4.4)

# %%
from clickhouse_connect import get_client
client = get_client(host='localhost', username='default', password="123")
print(client.query('SELECT 1').result_rows)
# Out:
# [(1,)]

# %%
client.command("""
CREATE TABLE trips
(
    `trip_id` UInt32,
    `vendor_id` Enum8('1' = 1, '2' = 2, '3' = 3, '4' = 4, 'CMT' = 5, 'VTS' = 6, 'DDS' = 7, 'B02512' = 10, 'B02598' = 11, 'B02617' = 12, 'B02682' = 13, 'B02764' = 14, '' = 15),
    `pickup_date` Date,
    `pickup_datetime` DateTime,
    `dropoff_date` Date,
    `dropoff_datetime` DateTime,
    `store_and_fwd_flag` UInt8,
    `rate_code_id` UInt8,
    `pickup_longitude` Float64,
    `pickup_latitude` Float64,
    `dropoff_longitude` Float64,
    `dropoff_latitude` Float64,
    `passenger_count` UInt8,
    `trip_distance` Float64,
    `fare_amount` Float32,
    `extra` Float32,
    `mta_tax` Float32,
    `tip_amount` Float32,
    `tolls_amount` Float32,
    `ehail_fee` Float32,
    `improvement_surcharge` Float32,
    `total_amount` Float32,
    `payment_type` Enum8('UNK' = 0, 'CSH' = 1, 'CRE' = 2, 'NOC' = 3, 'DIS' = 4),
    `trip_type` UInt8,
    `pickup` FixedString(25),
    `dropoff` FixedString(25),
    `cab_type` Enum8('yellow' = 1, 'green' = 2, 'uber' = 3),
    `pickup_nyct2010_gid` Int8,
    `pickup_ctlabel` Float32,
    `pickup_borocode` Int8,
    `pickup_ct2010` String,
    `pickup_boroct2010` String,
    `pickup_cdeligibil` String,
    `pickup_ntacode` FixedString(4),
    `pickup_ntaname` String,
    `pickup_puma` UInt16,
    `dropoff_nyct2010_gid` UInt8,
    `dropoff_ctlabel` Float32,
    `dropoff_borocode` UInt8,
    `dropoff_ct2010` String,
    `dropoff_boroct2010` String,
    `dropoff_cdeligibil` String,
    `dropoff_ntacode` FixedString(4),
    `dropoff_ntaname` String,
    `dropoff_puma` UInt16
)
ENGINE = MergeTree
PARTITION BY toYYYYMM(pickup_date)
ORDER BY pickup_datetime;
               """)
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 client.command("""
#       2 CREATE TABLE trips
#       3 (
#       4     `trip_id` UInt32,
#       5     `vendor_id` Enum8('1' = 1, '2' = 2, '3' = 3, '4' = 4, 'CMT' = 5, 'VTS' = 6, 'DDS' = 7, 'B02512' = 10, 'B02598' = 11, 'B02617' = 12, 'B02682' = 13, 'B02764' = 14, '' = 15),
#       6     `pickup_date` Date,
#       7     `pickup_datetime` DateTime,
#       8     `dropoff_date` Date,
#       9     `dropoff_datetime` DateTime,
#      10     `store_and_fwd_flag` UInt8,
#      11     `rate_code_id` UInt8,
#      12     `pickup_longitude` Float64,
#      13     `pickup_latitude` Float64,
#      14     `dropoff_longitude` Float64,
#      15     `dropoff_latitude` Float64,
#      16     `passenger_count` UInt8,
#      17     `trip_distance` Float64,
#      18     `fare_amount` Float32,
#      19     `extra` Float32,
#      20     `mta_tax` Float32,
#      21     `tip_amount` Float32,
#      22     `tolls_amount` Float32,
#      23     `ehail_fee` Float32,
#      24     `improvement_surcharge` Float32,
#      25     `total_amount` Float32,
#      26     `payment_type` Enum8('UNK' = 0, 'CSH' = 1, 'CRE' = 2, 'NOC' = 3, 'DIS' = 4),
#      27     `trip_type` UInt8,
#      28     `pickup` FixedString(25),
#      29     `dropoff` FixedString(25),
#      30     `cab_type` Enum8('yellow' = 1, 'green' = 2, 'uber' = 3),
#      31     `pickup_nyct2010_gid` Int8,
#      32     `pickup_ctlabel` Float32,
#      33     `pickup_borocode` Int8,
#      34     `pickup_ct2010` String,
#      35     `pickup_boroct2010` String,
#      36     `pickup_cdeligibil` String,
#      37     `pickup_ntacode` FixedString(4),
#      38     `pickup_ntaname` String,
#      39     `pickup_puma` UInt16,
#      40     `dropoff_nyct2010_gid` UInt8,
#      41     `dropoff_ctlabel` Float32,
#      42     `dropoff_borocode` UInt8,
#      43     `dropoff_ct2010` String,
#      44     `dropoff_boroct2010` String,
#      45     `dropoff_cdeligibil` String,
#      46     `dropoff_ntacode` FixedString(4),
#      47     `dropoff_ntaname` String,
#      48     `dropoff_puma` UInt16
#      49 )
#      50 ENGINE = MergeTree
#      51 PARTITION BY toYYYYMM(pickup_date)
#      52 ORDER BY pickup_datetime;
#      53                """)
#
# File /opt/anaconda3/envs/RAGSystems/lib/python3.12/site-packages/clickhouse_connect/driver/httpclient.py:412, in HttpClient.command(self, cmd, parameters, data, settings, use_database, external_data, transport_settings)
#     410 headers = dict_copy(headers, transport_settings)
#     411 method = 'POST' if payload or fields else 'GET'
# --> 412 response = self._raw_request(payload, params, headers, method, fields=fields, server_wait=False)
#     413 if response.data:
#     414     try:
#
# File /opt/anaconda3/envs/RAGSystems/lib/python3.12/site-packages/clickhouse_connect/driver/httpclient.py:547, in HttpClient._raw_request(self, data, params, headers, method, retries, stream, server_wait, fields, error_handler)
#     545     error_handler(response)
#     546 else:
# --> 547     self._error_handler(response)
#
# File /opt/anaconda3/envs/RAGSystems/lib/python3.12/site-packages/clickhouse_connect/driver/httpclient.py:468, in HttpClient._error_handler(self, response, retried)
#     465     response.close()
#     467 # Raise the appropriate exception class
# --> 468 raise OperationalError(err_str) if retried else DatabaseError(err_str) from None
#
# DatabaseError: Received ClickHouse exception, code: 57, server response: Code: 57. DB::Exception: Table default.trips already exists. (TABLE_ALREADY_EXISTS) (version 25.10.1.2351 (official build)) (for url http://localhost:8123)

# %%
client.command("""INSERT INTO trips
SELECT *
FROM file(
    'trips_*.gz',  -- or use 'trips_*.gz' if both are in same folder
    'TabSeparatedWithNames',
    "
    `trip_id` UInt32,
    `vendor_id` Enum8('1' = 1, '2' = 2, '3' = 3, '4' = 4, 'CMT' = 5, 'VTS' = 6, 'DDS' = 7, 'B02512' = 10, 'B02598' = 11, 'B02617' = 12, 'B02682' = 13, 'B02764' = 14, '' = 15),
    `pickup_date` Date,
    `pickup_datetime` DateTime,
    `dropoff_date` Date,
    `dropoff_datetime` DateTime,
    `store_and_fwd_flag` UInt8,
    `rate_code_id` UInt8,
    `pickup_longitude` Float64,
    `pickup_latitude` Float64,
    `dropoff_longitude` Float64,
    `dropoff_latitude` Float64,
    `passenger_count` UInt8,
    `trip_distance` Float64,
    `fare_amount` Float32,
    `extra` Float32,
    `mta_tax` Float32,
    `tip_amount` Float32,
    `tolls_amount` Float32,
    `ehail_fee` Float32,
    `improvement_surcharge` Float32,
    `total_amount` Float32,
    `payment_type` Enum8('UNK' = 0, 'CSH' = 1, 'CRE' = 2, 'NOC' = 3, 'DIS' = 4),
    `trip_type` UInt8,
    `pickup` FixedString(25),
    `dropoff` FixedString(25),
    `cab_type` Enum8('yellow' = 1, 'green' = 2, 'uber' = 3),
    `pickup_nyct2010_gid` Int8,
    `pickup_ctlabel` Float32,
    `pickup_borocode` Int8,
    `pickup_ct2010` String,
    `pickup_boroct2010` String,
    `pickup_cdeligibil` String,
    `pickup_ntacode` FixedString(4),
    `pickup_ntaname` String,
    `pickup_puma` UInt16,
    `dropoff_nyct2010_gid` UInt8,
    `dropoff_ctlabel` Float32,
    `dropoff_borocode` UInt8,
    `dropoff_ct2010` String,
    `dropoff_boroct2010` String,
    `dropoff_cdeligibil` String,
    `dropoff_ntacode` FixedString(4),
    `dropoff_ntaname` String,
    `dropoff_puma` UInt16
    "
) SETTINGS input_format_try_infer_datetimes = 0;
               """)

# %%
client.command("""SELECT COUNT() FROM trips""")
# Out:
# 1999657

# %%
client.command("""
    SELECT round(avg(tip_amount), 2) FROM trips
    """)
# Out:
# '1.68'

# %%
client.command("""
SELECT
    passenger_count,
    ceil(avg(total_amount),2) AS average_total_amount
FROM trips
GROUP BY passenger_count
               """)
# Out:
# ['0',
#  '22.69\n1',
#  '15.97\n2',
#  '17.15\n3',
#  '16.76\n4',
#  '17.33\n5',
#  '16.35\n6',
#  '16.04\n7',
#  '59.8\n8',
#  '36.41\n9',
#  '9.81']

# %%
client.command("""
SELECT
    pickup_date,
    pickup_ntaname,
    SUM(1) AS number_of_trips
FROM trips
GROUP BY pickup_date, pickup_ntaname
ORDER BY pickup_date ASC""")
# Out:
# ['2015-07-01',
#  'Melrose South-Mott Haven North',
#  '1\n2015-07-01',
#  'park-cemetery-etc-Manhattan',
#  '169\n2015-07-01',
#  'Bedford',
#  '8\n2015-07-01',
#  'South Jamaica',
#  '1\n2015-07-01',
#  'Upper West Side',
#  '593\n2015-07-01',
#  'Borough Park',
#  '1\n2015-07-01',
#  'Midtown-Midtown South',
#  '2258\n2015-07-01',
#  'Turtle Bay-East Midtown',
#  '999\n2015-07-01',
#  'East Village',
#  '337\n2015-07-01',
#  'Brooklyn Heights-Cobble Hill',
#  '13\n2015-07-01',
#  'Crown Heights North',
#  '3\n2015-07-01',
#  'Central Harlem South',
#  '33\n2015-07-01',
#  '',
#  '205\n2015-07-01',
#  'North Side-South Side',
#  '31\n2015-07-01',
#  'Woodside',
#  '8\n2015-07-01',
#  'Elmhurst',
#  '4\n2015-07-01',
#  'Flatbush',
#  '2\n2015-07-01',
#  'Prospect Heights',
#  '5\n2015-07-01',
#  'Newark Airport',
#  '1\n2015-07-01',
#  'Old Astoria',
#  '5\n2015-07-01',
#  'Bushwick North',
#  '2\n2015-07-01',
#  'Battery Park City-Lower Manhattan',
#  '363\n2015-07-01',
#  'Midwood',
#  '2\n2015-07-01',
#  'Forest Hills',
#  '5\n2015-07-01',
#  'Prospect Lefferts Gardens-Wingate',
#  '4\n2015-07-01',
#  'Soundview-Castle Hill-Clason Point-Harding Park',
#  '1\n2015-07-01',
#  'Lenox Hill-Roosevelt Island',
#  '519\n2015-07-01',
#  'Lincoln Square',
#  '507\n2015-07-01',
#  'Baisley Park',
#  '1\n2015-07-01',
#  'Carroll Gardens-Columbia Street-Red Hook',
#  '19\n2015-07-01',
#  'Chinatown',
#  '200\n2015-07-01',
#  'East Harlem South',
#  '67\n2015-07-01',
#  'Erasmus',
#  '1\n2015-07-01',
#  'DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill',
#  '53\n2015-07-01',
#  'East Elmhurst',
#  '4\n2015-07-01',
#  'Flushing',
#  '1\n2015-07-01',
#  'Hunters Point-Sunnyside-West Maspeth',
#  '42\n2015-07-01',
#  'SoHo-TriBeCa-Civic Center-Little Italy',
#  '621\n2015-07-01',
#  'Highbridge',
#  '1\n2015-07-01',
#  'East Harlem North',
#  '32\n2015-07-01',
#  'Sunset Park West',
#  '3\n2015-07-01',
#  'Fordham South',
#  '2\n2015-07-01',
#  'Upper East Side-Carnegie Hill',
#  '931\n2015-07-01',
#  'Springfield Gardens South-Brookville',
#  '2\n2015-07-01',
#  'Elmhurst-Maspeth',
#  '2\n2015-07-01',
#  'Briarwood-Jamaica Hills',
#  '3\n2015-07-01',
#  'Airport',
#  '550\n2015-07-01',
#  'Greenpoint',
#  '7\n2015-07-01',
#  'Rego Park',
#  '1\n2015-07-01',
#  'Stuyvesant Town-Cooper Village',
#  '44\n2015-07-01',
#  'Maspeth',
#  '1\n2015-07-01',
#  'park-cemetery-etc-Queens',
#  '6\n2015-07-01',
#  'Williamsburg',
#  '1\n2015-07-01',
#  'Jackson Heights',
#  '4\n2015-07-01',
#  'Yorkville',
#  '378\n2015-07-01',
#  'Gramercy',
#  '344\n2015-07-01',
#  'West Village',
#  '836\n2015-07-01',
#  'Fort Greene',
#  '13\n2015-07-01',
#  'Central Harlem North-Polo Grounds',
#  '6\n2015-07-01',
#  'Stuyvesant Heights',
#  '1\n2015-07-01',
#  'Queensbridge-Ravenswood-Long Island City',
#  '9\n2015-07-01',
#  'Hudson Yards-Chelsea-Flatiron-Union Square',
#  '1206\n2015-07-01',
#  'Crown Heights South',
#  '1\n2015-07-01',
#  'Brighton Beach',
#  '1\n2015-07-01',
#  'Jamaica',
#  '2\n2015-07-01',
#  'Kensington-Ocean Parkway',
#  '3\n2015-07-01',
#  'Morningside Heights',
#  '97\n2015-07-01',
#  'Clinton',
#  '464\n2015-07-01',
#  'Murray Hill-Kips Bay',
#  '611\n2015-07-01',
#  'Bushwick South',
#  '5\n2015-07-01',
#  'Washington Heights North',
#  '2\n2015-07-01',
#  'Steinway',
#  '9\n2015-07-01',
#  'East Concourse-Concourse Village',
#  '1\n2015-07-01',
#  'Astoria',
#  '22\n2015-07-01',
#  'Washington Heights South',
#  '5\n2015-07-01',
#  'Clinton Hill',
#  '8\n2015-07-01',
#  'East Williamsburg',
#  '8\n2015-07-01',
#  'Norwood',
#  '1\n2015-07-01',
#  'Park Slope-Gowanus',
#  '29\n2015-07-01',
#  'West Concourse',
#  '2\n2015-07-01',
#  'Lower East Side',
#  '62\n2015-07-01',
#  'University Heights-Morris Heights',
#  '2\n2015-07-01',
#  'Hamilton Heights',
#  '14\n2015-07-01',
#  'Manhattanville',
#  '12\n2015-07-02',
#  'Flatbush',
#  '1\n2015-07-02',
#  'Newark Airport',
#  '1\n2015-07-02',
#  'Old Astoria',
#  '9\n2015-07-02',
#  'Bushwick North',
#  '2\n2015-07-02',
#  'East Harlem South',
#  '65\n2015-07-02',
#  'Bensonhurst West',
#  '1\n2015-07-02',
#  'Battery Park City-Lower Manhattan',
#  '334\n2015-07-02',
#  'Lenox Hill-Roosevelt Island',
#  '545\n2015-07-02',
#  'Woodside',
#  '1\n2015-07-02',
#  'Elmhurst',
#  '6\n2015-07-02',
#  'Marble Hill-Inwood',
#  '1\n2015-07-02',
#  'Bedford',
#  '5\n2015-07-02',
#  'East Village',
#  '390\n2015-07-02',
#  'Mott Haven-Port Morris',
#  '3\n2015-07-02',
#  'Bay Ridge',
#  '1\n2015-07-02',
#  'Prospect Heights',
#  '5\n2015-07-02',
#  'Turtle Bay-East Midtown',
#  '850\n2015-07-02',
#  'Dyker Heights',
#  '1\n2015-07-02',
#  'Flushing',
#  '1\n2015-07-02',
#  'Carroll Gardens-Columbia Street-Red Hook',
#  '19\n2015-07-02',
#  'Brooklyn Heights-Cobble Hill',
#  '7\n2015-07-02',
#  'park-cemetery-etc-Manhattan',
#  '153\n2015-07-02',
#  'North Corona',
#  '1\n2015-07-02',
#  'Chinatown',
#  '187\n2015-07-02',
#  'Erasmus',
#  '1\n2015-07-02',
#  'East Elmhurst',
#  '2\n2015-07-02',
#  'North Side-South Side',
#  '39\n2015-07-02',
#  'DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill',
#  '36\n2015-07-02',
#  'Crown Heights North',
#  '6\n2015-07-02',
#  'Lincoln Square',
#  '442\n2015-07-02',
#  'Prospect Lefferts Gardens-Wingate',
#  '3\n2015-07-02',
#  'Central Harlem South',
#  '19\n2015-07-02',
#  'Midwood',
#  '1\n2015-07-02',
#  'Upper West Side',
#  '558\n2015-07-02',
#  'Forest Hills',
#  '4\n2015-07-02',
#  'Midtown-Midtown South',
#  '2098\n2015-07-02',
#  '',
#  '187\n2015-07-02',
#  'Park Slope-Gowanus',
#  '22\n2015-07-02',
#  'Williamsburg',
#  '3\n2015-07-02',
#  'Lower East Side',
#  '58\n2015-07-02',
#  'Yorkville',
#  '357\n2015-07-02',
#  'Gramercy',
#  '349\n2015-07-02',
#  'Fort Greene',
#  '10\n2015-07-02',
#  'West Village',
#  '840\n2015-07-02',
#  'Hamilton Heights',
#  '14\n2015-07-02',
#  'Airport',
#  '517\n2015-07-02',
#  'Seagate-Coney Island',
#  '1\n2015-07-02',
#  'Greenpoint',
#  '7\n2015-07-02',
#  'Rego Park',
#  '1\n2015-07-02',
#  'East Williamsburg',
#  '13\n2015-07-02',
#  'Kensington-Ocean Parkway',
#  '1\n2015-07-02',
#  'Washington Heights South',
#  '10\n2015-07-02',
#  'SoHo-TriBeCa-Civic Center-Little Italy',
#  '548\n2015-07-02',
#  'Hunters Point-Sunnyside-West Maspeth',
#  '37\n2015-07-02',
#  'Morningside Heights',
#  '82\n2015-07-02',
#  'Washington Heights North',
#  '2\n2015-07-02',
#  'Murray Hill-Kips Bay',
#  '613\n2015-07-02',
#  'Stuyvesant Heights',
#  '2\n2015-07-02',
#  'Cypress Hills-City Line',
#  '1\n2015-07-02',
#  'Springfield Gardens South-Brookville',
#  '1\n2015-07-02',
#  'East Concourse-Concourse Village',
#  '1\n2015-07-02',
#  'Morrisania-Melrose',
#  '1\n2015-07-02',
#  'West Concourse',
#  '2\n2015-07-02',
#  'Jackson Heights',
#  '5\n2015-07-02',
#  'South Ozone Park',
#  '2\n2015-07-02',
#  'Bellerose',
#  '1\n2015-07-02',
#  'Richmond Hill',
#  '2\n2015-07-02',
#  'Manhattanville',
#  '5\n2015-07-02',
#  'Bushwick South',
#  '5\n2015-07-02',
#  'Steinway',
#  '7\n2015-07-02',
#  'Astoria',
#  '24\n2015-07-02',
#  'Queensbridge-Ravenswood-Long Island City',
#  '15\n2015-07-02',
#  'Clinton Hill',
#  '5\n2015-07-02',
#  'Hudson Yards-Chelsea-Flatiron-Union Square',
#  '1131\n2015-07-02',
#  'Upper East Side-Carnegie Hill',
#  '799\n2015-07-02',
#  'Rugby-Remsen Village',
#  '1\n2015-07-02',
#  'Canarsie',
#  '2\n2015-07-02',
#  'Jamaica',
#  '2\n2015-07-02',
#  'Central Harlem North-Polo Grounds',
#  '16\n2015-07-02',
#  'Stuyvesant Town-Cooper Village',
#  '40\n2015-07-02',
#  'Briarwood-Jamaica Hills',
#  '1\n2015-07-02',
#  'Clinton',
#  '471\n2015-07-02',
#  'Elmhurst-Maspeth',
#  '2\n2015-07-02',
#  'park-cemetery-etc-Queens',
#  '1\n2015-07-02',
#  'Sunset Park West',
#  '1\n2015-07-02',
#  'Kew Gardens Hills',
#  '1\n2015-07-02',
#  'East Harlem North',
#  '37\n2015-07-03',
#  'Battery Park City-Lower Manhattan',
#  '357\n2015-07-03',
#  'West Concourse',
#  '5\n2015-07-03',
#  'Hudson Yards-Chelsea-Flatiron-Union Square',
#  '974\n2015-07-03',
#  'Queensbridge-Ravenswood-Long Island City',
#  '15\n2015-07-03',
#  'Manhattanville',
#  '12\n2015-07-03',
#  'Rugby-Remsen Village',
#  '1\n2015-07-03',
#  'Lenox Hill-Roosevelt Island',
#  '340\n2015-07-03',
#  'Bushwick South',
#  '8\n2015-07-03',
#  'Astoria',
#  '28\n2015-07-03',
#  'Jackson Heights',
#  '13\n2015-07-03',
#  'Steinway',
#  '17\n2015-07-03',
#  'Clinton Hill',
#  '5\n2015-07-03',
#  'Brighton Beach',
#  '1\n2015-07-03',
#  'Windsor Terrace',
#  '3\n2015-07-03',
#  'Jamaica',
#  '5\n2015-07-03',
#  'Clinton',
#  '476\n2015-07-03',
#  'East Harlem North',
#  '47\n2015-07-03',
#  'Sunset Park West',
#  '2\n2015-07-03',
#  'Kew Gardens Hills',
#  '1\n2015-07-03',
#  'Elmhurst-Maspeth',
#  '2\n2015-07-03',
#  'Van Cortlandt Village',
#  '1\n2015-07-03',
#  'Williamsburg',
#  '2\n2015-07-03',
#  'Gramercy',
#  '255\n2015-07-03',
#  'Yorkville',
#  '318\n2015-07-03',
#  'Spuyten Duyvil-Kingsbridge',
#  '1\n2015-07-03',
#  'East Williamsburg',
#  '12\n2015-07-03',
#  'Fort Greene',
#  '14\n2015-07-03',
#  'West Village',
#  '789\n2015-07-03',
#  'Turtle Bay-East Midtown',
#  '554\n2015-07-03',
#  'Airport',
#  '427\n2015-07-03',
#  'Park Slope-Gowanus',
#  '15\n2015-07-03',
#  'Brooklyn Heights-Cobble Hill',
#  '7\n2015-07-03',
#  'Rego Park',
#  '2\n2015-07-03',
#  'Douglas Manor-Douglaston-Little Neck',
#  '1\n2015-07-03',
#  'Greenpoint',
#  '5\n2015-07-03',
#  'Lower East Side',
#  '58\n2015-07-03',
#  'Melrose South-Mott Haven North',
#  '1\n2015-07-03',
#  'Maspeth',
#  '1\n2015-07-03',
#  'park-cemetery-etc-Manhattan',
#  '174\n2015-07-03',
#  'Hamilton Heights',
#  '10\n2015-07-03',
#  'Ocean Hill',
#  '1\n2015-07-03',
#  'Stuyvesant Heights',
#  '2\n2015-07-03',
#  '',
#  '148\n2015-07-03',
#  'Morningside Heights',
#  '87\n2015-07-03',
#  'Murray Hill-Kips Bay',
#  '419\n2015-07-03',
#  'Hunts Point',
#  '1\n2015-07-03',
#  'Flushing',
#  '1\n2015-07-03',
#  'Dyker Heights',
#  '1\n2015-07-03',
#  'North Corona',
#  '1\n2015-07-03',
#  'North Side-South Side',
#  '69\n2015-07-03',
#  'Kensington-Ocean Parkway',
#  '2\n2015-07-03',
#  'Mott Haven-Port Morris',
#  '2\n2015-07-03',
#  'Prospect Heights',
#  '2\n2015-07-03',
#  'Chinatown',
#  '252\n2015-07-03',
#  'Erasmus',
#  '1\n2015-07-03',
#  'East Elmhurst',
#  '2\n2015-07-03',
#  'Carroll Gardens-Columbia Street-Red Hook',
#  '17\n2015-07-03',
#  'Lincoln Square',
#  '360\n2015-07-03',
#  'Upper West Side',
#  '466\n2015-07-03',
#  'Murray Hill',
#  '1\n2015-07-03',
#  'Baisley Park',
#  '1\n2015-07-03',
#  'Parkchester',
#  '1\n2015-07-03',
#  'Midtown-Midtown South',
#  '1675\n2015-07-03',
#  'Crown Heights North',
#  '5\n2015-07-03',
#  'DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill',
#  '32\n2015-07-03',
#  'Washington Heights South',
#  '8\n2015-07-03',
#  'Forest Hills',
#  '3\n2015-07-03',
#  'Washington Heights North',
#  '1\n2015-07-03',
#  'Hunters Point-Sunnyside-West Maspeth',
#  '33\n2015-07-03',
#  'Central Harlem South',
#  '37\n2015-07-03',
#  'SoHo-TriBeCa-Civic Center-Little Italy',
#  '489\n2015-07-03',
#  'College Point',
#  '1\n2015-07-03',
#  'Flatbush',
#  '2\n2015-07-03',
#  'East Harlem South',
#  '73\n2015-07-03',
#  'Old Astoria',
#  '13\n2015-07-03',
#  'Newark Airport',
#  '1\n2015-07-03',
#  'Bushwick North',
#  '6\n2015-07-03',
#  'park-cemetery-etc-Brooklyn',
#  '1\n2015-07-03',
#  'University Heights-Morris Heights',
#  '1\n2015-07-03',
#  'Upper East Side-Carnegie Hill',
#  '483\n2015-07-03',
#  'Elmhurst',
#  '2\n2015-07-03',
#  'East Concourse-Concourse Village',
#  '1\n2015-07-03',
#  'Woodside',
#  '11\n2015-07-03',
#  'park-cemetery-etc-Queens',
#  '1\n2015-07-03',
#  'Bedford',
#  '5\n2015-07-03',
#  'Stuyvesant Town-Cooper Village',
#  '45\n2015-07-03',
#  'Borough Park',
#  '1\n2015-07-03',
#  'Marble Hill-Inwood',
#  '1\n2015-07-03',
#  'Central Harlem North-Polo Grounds',
#  '16\n2015-07-03',
#  'Briarwood-Jamaica Hills',
#  '1\n2015-07-03',
#  'East Village',
#  '425\n2015-07-04',
#  'Rosedale',
#  '1\n2015-07-04',
#  'Woodside',
#  '9\n2015-07-04',
#  'Elmhurst',
#  '9\n2015-07-04',
#  'Elmhurst-Maspeth',
#  '3\n2015-07-04',
#  'Woodlawn-Wakefield',
#  '2\n2015-07-04',
#  'Carroll Gardens-Columbia Street-Red Hook',
#  '11\n2015-07-04',
#  'Old Astoria',
#  '10\n2015-07-04',
#  'Windsor Terrace',
#  '1\n2015-07-04',
#  'Flatbush',
#  '3\n2015-07-04',
#  'Allerton-Pelham Gardens',
#  '1\n2015-07-04',
#  'Bushwick North',
#  '5\n2015-07-04',
#  'Sunset Park West',
#  '2\n2015-07-04',
#  'East Harlem North',
#  '37\n2015-07-04',
#  'Morrisania-Melrose',
#  '1\n2015-07-04',
#  'Queens Village',
#  '1\n2015-07-04',
#  'Bedford',
#  '6\n2015-07-04',
#  'Jackson Heights',
#  '9\n2015-07-04',
#  'Prospect Lefferts Gardens-Wingate',
#  '5\n2015-07-04',
#  'East Village',
#  '379\n2015-07-04',
#  'Washington Heights South',
#  '14\n2015-07-04',
#  'Lindenwood-Howard Beach',
#  '1\n2015-07-04',
#  'Rugby-Remsen Village',
#  '1\n2015-07-04',
#  'Washington Heights North',
#  '5\n2015-07-04',
#  'Kew Gardens',
#  '1\n2015-07-04',
#  'Chinatown',
#  '225\n2015-07-04',
#  'Upper East Side-Carnegie Hill',
#  '322\n2015-07-04',
#  'Morningside Heights',
#  '45\n2015-07-04',
#  'park-cemetery-etc-Brooklyn',
#  '5\n2015-07-04',
#  'East Elmhurst',
#  '1\n2015-07-04',
#  'Murray Hill-Kips Bay',
#  '383\n2015-07-04',
#  'DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill',
#  '32\n2015-07-04',
#  'Stuyvesant Heights',
#  '1\n2015-07-04',
#  'Bay Ridge',
#  '1\n2015-07-04',
#  'Hunts Point',
#  '1\n2015-07-04',
#  'Bensonhurst East',
#  '1\n2015-07-04',
#  'Battery Park City-Lower Manhattan',
#  '245\n2015-07-04',
#  'Crown Heights South',
#  '1\n2015-07-04',
#  'Ridgewood',
#  '3\n2015-07-04',
#  'North Corona',
#  '1\n2015-07-04',
#  'Park Slope-Gowanus',
#  '19\n2015-07-04',
#  'Lower East Side',
#  '81\n2015-07-04',
#  'Hamilton Heights',
#  '11\n2015-07-04',
#  'Forest Hills',
#  '4\n2015-07-04',
#  'Baisley Park',
#  '1\n2015-07-04',
#  'Stuyvesant Town-Cooper Village',
#  '27\n2015-07-04',
#  'Lincoln Square',
#  '290\n2015-07-04',
#  'Seagate-Coney Island',
#  '1\n2015-07-04',
#  'East Williamsburg',
#  '16\n2015-07-04',
#  'Briarwood-Jamaica Hills',
#  '1\n2015-07-04',
#  'Queensbridge-Ravenswood-Long Island City',
#  '40\n2015-07-04',
#  'Greenpoint',
#  '15\n2015-07-04',
#  'Rego Park',
#  '1\n2015-07-04',
#  'Crown Heights North',
#  '8\n2015-07-04',
#  'Airport',
#  '337\n2015-07-04',
#  'Central Harlem South',
#  '43\n2015-07-04',
#  'Lenox Hill-Roosevelt Island',
#  '285\n2015-07-04',
#  'Hudson Yards-Chelsea-Flatiron-Union Square',
#  '805\n2015-07-04',
#  'Williamsburg',
#  '3\n2015-07-04',
#  'Upper West Side',
#  '337\n2015-07-04',
#  'Fort Greene',
#  '14\n2015-07-04',
#  'West Village',
#  '616\n2015-07-04',
#  'West Brighton',
#  '1\n2015-07-04',
#  'University Heights-Morris Heights',
#  '1\n2015-07-04',
#  'Yorkville',
#  '205\n2015-07-04',
#  'Gramercy',
#  '196\n2015-07-04',
#  'Midtown-Midtown South',
#  '1515\n2015-07-04',
#  'Prospect Heights',
#  '6\n2015-07-04',
#  'Mott Haven-Port Morris',
#  '6\n2015-07-04',
#  'Claremont-Bathgate',
#  '1\n2015-07-04',
#  'Central Harlem North-Polo Grounds',
#  '13\n2015-07-04',
#  'Whitestone',
#  '1\n2015-07-04',
#  'Homecrest',
#  '1\n2015-07-04',
#  'Highbridge',
#  '1\n2015-07-04',
#  'Ocean Hill',
#  '1\n2015-07-04',
#  'North Side-South Side',
#  '59\n2015-07-04',
#  '',
#  '117\n2015-07-04',
#  'Steinway',
#  '10\n2015-07-04',
#  'Eastchester-Edenwald-Baychester',
#  '1\n2015-07-04',
#  'Astoria',
#  '41\n2015-07-04',
#  'Bushwick South',
#  '15\n2015-07-04',
#  'Marble Hill-Inwood',
#  '2\n2015-07-04',
#  'Clinton Hill',
#  '9\n2015-07-04',
#  'West Concourse',
#  '1\n2015-07-04',
#  'Brooklyn Heights-Cobble Hill',
#  '15\n2015-07-04',
#  'Turtle Bay-East Midtown',
#  '445\n2015-07-04',
#  'Richmond Hill',
#  '1\n2015-07-04',
#  'Melrose South-Mott Haven North',
#  '4\n2015-07-04',
#  'Manhattanville',
#  '11\n2015-07-04',
#  'park-cemetery-etc-Manhattan',
#  '144\n2015-07-04',
#  'Sheepshead Bay-Gerritsen Beach-Manhattan Beach',
#  '1\n2015-07-04',
#  'SoHo-TriBeCa-Civic Center-Little Italy',
#  '396\n2015-07-04',
#  'Hunters Point-Sunnyside-West Maspeth',
#  '45\n2015-07-04',
#  'East Harlem South',
#  '52\n2015-07-04',
#  'Bensonhurst West',
#  '1\n2015-07-04',
#  'Clinton',
#  '449\n2015-07-05',
#  'Astoria',
#  '32\n2015-07-05',
#  'Bronxdale',
#  '1\n2015-07-05',
#  'Steinway',
#  '5\n2015-07-05',
#  'Bushwick South',
#  '12\n2015-07-05',
#  'Clinton Hill',
#  '6\n2015-07-05',
#  'West Concourse',
#  '2\n2015-07-05',
#  'Marble Hill-Inwood',
#  '1\n2015-07-05',
#  'Manhattanville',
#  '13\n2015-07-05',
#  'East Harlem South',
#  '71\n2015-07-05',
#  'Washington Heights South',
#  '10\n2015-07-05',
#  'Prospect Lefferts Gardens-Wingate',
#  '2\n2015-07-05',
#  'Clinton',
#  '477\n2015-07-05',
#  'Rego Park',
#  '2\n2015-07-05',
#  'Greenpoint',
#  '6\n2015-07-05',
#  'Airport',
#  '656\n2015-07-05',
#  'Upper West Side',
#  '382\n2015-07-05',
#  'Battery Park City-Lower Manhattan',
#  '256\n2015-07-05',
#  'Midtown-Midtown South',
#  '1759\n2015-07-05',
#  'Hudson Yards-Chelsea-Flatiron-Union Square',
#  '714\n2015-07-05',
#  'Crown Heights North',
#  '9\n2015-07-05',
#  'Williamsburg',
#  '4\n2015-07-05',
#  'Kingsbridge Heights',
#  '1\n2015-07-05',
#  'Central Harlem South',
#  '38\n2015-07-05',
#  'Fort Greene',
#  '16\n2015-07-05',
#  'West Village',
#  '567\n2015-07-05',
#  'Gramercy',
#  '190\n2015-07-05',
#  'Yorkville',
#  '211\n2015-07-05',
#  'Upper East Side-Carnegie Hill',
#  '335\n2015-07-05',
#  'Queensbridge-Ravenswood-Long Island City',
#  '18\n2015-07-05',
#  'park-cemetery-etc-Brooklyn',
#  '1\n2015-07-05',
#  'Westchester-Unionport',
#  '1\n2015-07-05',
#  'Stuyvesant Town-Cooper Village',
#  '37\n2015-07-05',
#  'North Side-South Side',
#  '77\n2015-07-05',
#  'Sunset Park East',
#  '1\n2015-07-05',
#  'Briarwood-Jamaica Hills',
#  '4\n2015-07-05',
#  'Stapleton-Rosebank',
#  '1\n2015-07-05',
#  'Prospect Heights',
#  '7\n2015-07-05',
#  'Mott Haven-Port Morris',
#  '2\n2015-07-05',
#  'Ocean Hill',
#  '1\n2015-07-05',
#  'park-cemetery-etc-Queens',
#  '2\n2015-07-05',
#  'Stuyvesant Heights',
#  '4\n2015-07-05',
#  'Kew Gardens',
#  '1\n2015-07-05',
#  'Chinatown',
#  '224\n2015-07-05',
#  'Crown Heights South',
#  '1\n2015-07-05',
#  'East Elmhurst',
#  '9\n2015-07-05',
#  'East Tremont',
#  '1\n2015-07-05',
#  'Flushing',
#  '2\n2015-07-05',
#  'Hunts Point',
#  '1\n2015-07-05',
#  'Morningside Heights',
#  '58\n2015-07-05',
#  'Lenox Hill-Roosevelt Island',
#  '249\n2015-07-05',
#  'Ridgewood',
#  '1\n2015-07-05',
#  'Murray Hill-Kips Bay',
#  '408\n2015-07-05',
#  'DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill',
#  '35\n2015-07-05',
#  'East Williamsburg',
#  '21\n2015-07-05',
#  'Forest Hills',
#  '4\n2015-07-05',
#  'Park Slope-Gowanus',
#  '22\n2015-07-05',
#  'Brownsville',
#  '1\n2015-07-05',
#  'Murray Hill',
#  '1\n2015-07-05',
#  'Baisley Park',
#  '3\n2015-07-05',
#  '',
#  '149\n2015-07-05',
#  'Lincoln Square',
#  '308\n2015-07-05',
#  'Central Harlem North-Polo Grounds',
#  '17\n2015-07-05',
#  'Lower East Side',
#  '61\n2015-07-05',
#  'Hamilton Heights',
#  '19\n2015-07-05',
#  'Brooklyn Heights-Cobble Hill',
#  '13\n2015-07-05',
#  'Turtle Bay-East Midtown',
#  '497\n2015-07-05',
#  'Windsor Terrace',
#  '1\n2015-07-05',
#  'Elmhurst',
#  '5\n2015-07-05',
#  'Woodside',
#  '9\n2015-07-05',
#  'Carroll Gardens-Columbia Street-Red Hook',
#  '11\n2015-07-05',
#  'park-cemetery-etc-Manhattan',
#  '142\n2015-07-05',
#  'Melrose South-Mott Haven North',
#  '2\n2015-07-05',
#  'East Harlem North',
#  '39\n2015-07-05',
#  'Sunset Park West',
#  '3\n2015-07-05',
#  'Old Astoria',
#  '6\n2015-07-05',
#  'Flatbush',
#  '4\n2015-07-05',
#  'Bushwick North',
#  '6\n2015-07-05',
#  'Spuyten Duyvil-Kingsbridge',
#  '3\n2015-07-05',
#  'Eastchester-Edenwald-Baychester',
#  '1\n2015-07-05',
#  'Elmhurst-Maspeth',
#  '3\n2015-07-05',
#  'South Jamaica',
#  '1\n2015-07-05',
#  'Bedford',
#  '7\n2015-07-05',
#  'East Village',
#  '336\n2015-07-05',
#  'Rugby-Remsen Village',
#  '2\n2015-07-05',
#  'Springfield Gardens South-Brookville',
#  '1\n2015-07-05',
#  'Hunters Point-Sunnyside-West Maspeth',
#  '49\n2015-07-05',
#  'Jackson Heights',
#  '12\n2015-07-05',
#  'SoHo-TriBeCa-Civic Center-Little Italy',
#  '373\n2015-07-05',
#  'South Ozone Park',
#  '1\n2015-07-06',
#  'Prospect Heights',
#  '6\n2015-07-06',
#  'Claremont-Bathgate',
#  '1\n2015-07-06',
#  'Mott Haven-Port Morris',
#  '2\n2015-07-06',
#  'Clinton',
#  '387\n2015-07-06',
#  'Ocean Parkway South',
#  '1\n2015-07-06',
#  'Upper East Side-Carnegie Hill',
#  '739\n2015-07-06',
#  'park-cemetery-etc-Brooklyn',
#  '1\n2015-07-06',
#  'North Side-South Side',
#  '18\n2015-07-06',
#  'Prospect Lefferts Gardens-Wingate',
#  '3\n2015-07-06',
#  'Crown Heights North',
#  '1\n2015-07-06',
#  'West Concourse',
#  '2\n2015-07-06',
#  'Stuyvesant Town-Cooper Village',
#  '38\n2015-07-06',
#  'Manhattanville',
#  '7\n2015-07-06',
#  'Central Harlem South',
#  '25\n2015-07-06',
#  'Richmond Hill',
#  '2\n2015-07-06',
#  'Bellerose',
#  '1\n2015-07-06',
#  'Astoria',
#  '15\n2015-07-06',
#  'Steinway',
#  '12\n2015-07-06',
#  'Bushwick South',
#  '3\n2015-07-06',
#  'Upper West Side',
#  '516\n2015-07-06',
#  'Clinton Hill',
#  '3\n2015-07-06',
#  'Midtown-Midtown South',
#  '2046\n2015-07-06',
#  'Hudson Yards-Chelsea-Flatiron-Union Square',
#  '902\n2015-07-06',
#  'Queensbridge-Ravenswood-Long Island City',
#  '18\n2015-07-06',
#  'Kensington-Ocean Parkway',
#  '2\n2015-07-06',
#  'East Harlem South',
#  '68\n2015-07-06',
#  'Bensonhurst West',
#  '1\n2015-07-06',
#  'Washington Heights North',
#  '1\n2015-07-06',
#  'Marble Hill-Inwood',
#  '2\n2015-07-06',
#  'West Village',
#  '592\n2015-07-06',
#  'Fort Greene',
#  '6\n2015-07-06',
#  'Battery Park City-Lower Manhattan',
#  '278\n2015-07-06',
#  'Gramercy',
#  '244\n2015-07-06',
#  'Yorkville',
#  '294\n2015-07-06',
#  'Washington Heights South',
#  '9\n2015-07-06',
#  'Greenpoint',
#  '6\n2015-07-06',
#  'Airport',
#  '749\n2015-07-06',
#  'Baisley Park',
#  '1\n2015-07-06',
#  'Lincoln Square',
#  '371\n2015-07-06',
#  'Jackson Heights',
#  '7\n2015-07-06',
#  'park-cemetery-etc-Manhattan',
#  '157\n2015-07-06',
#  'Brooklyn Heights-Cobble Hill',
#  '9\n2015-07-06',
#  'Turtle Bay-East Midtown',
#  '752\n2015-07-06',
#  'DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill',
#  '18\n2015-07-06',
#  'Spuyten Duyvil-Kingsbridge',
#  '1\n2015-07-06',
#  'Central Harlem North-Polo Grounds',
#  '9\n2015-07-06',
#  'West Farms-Bronx River',
#  '1\n2015-07-06',
#  'Forest Hills',
#  '3\n2015-07-06',
#  'Flushing',
#  '1\n2015-07-06',
#  'East New York',
#  '1\n2015-07-06',
#  'Van Cortlandt Village',
#  '1\n2015-07-06',
#  'Elmhurst-Maspeth',
#  '4\n2015-07-06',
#  'Windsor Terrace',
#  '2\n2015-07-06',
#  'Chinatown',
#  ...]

# %%
client.command("""
SELECT
    avg(tip_amount) AS avg_tip,
    avg(fare_amount) AS avg_fare,
    avg(passenger_count) AS avg_passenger,
    count() AS count,
    truncate(date_diff('second', pickup_datetime, dropoff_datetime)/60) as trip_minutes
FROM trips
WHERE trip_minutes > 0
#  '4',
#  '1',
#  '1',
#  '841\n1.6200000047683716',
#  '10',
#  '5',
#  '1',
#  '835\n0',
#  '41',
#  '1',
#  '1',
#  '824\n2.3600001335144043',
#  '11',
#  '1',
#  '1',
#  '823\n0',
#  '23',
#  '6',
#  '1',
#  '820\n0',
#  '16',
#  '1',
#  '1',
#  '819\n1.3199999332427979',
#  '8',
#  '1',
#  '1',
#  '816\n0',
#  '15.5',
#  '1',
#  '1',
#  '815\n2.0799999237060547',
#  '20',
#  '1',
#  '1',
#  '813\n5.164999842643738',
#  '22.25',
#  '1.5',
#  '2',
#  '805\n1.7599999904632568',
#  '8',
#  '1',
#  '1',
#  '802\n69.06999969482422',
#  '109.5',
#  '1',
#  '1',
#  '793\n11.670000076293945',
#  '52',
#  '1',
#  '1',
#  '780\n3.040000081062317',
#  '23.75',
#  '1',
#  '2',
#  '777\n1.4700000286102295',
#  '9',
#  '5',
#  '1',
#  '772\n0',
#  '26',
#  '5',
#  '1',
#  '766\n0.4699999988079071',
#  '6',
#  '1',
#  '2',
#  '765\n0',
#  '17.299999237060547',
#  '1',
#  '1',
#  '764\n24.799999237060547',
#  '165',
#  '1',
#  '1',
#  '762\n0',
#  '16',
#  '2',
#  '1',
#  '759\n6.570000171661377',
#  '26.5',
#  '1',
#  '1',
#  '758\n0',
#  '4',
#  '6',
#  '1',
#  '755\n0',
#  '27',
#  '1',
#  '1',
#  '754\n1.3199999332427979',
#  '8',
#  '1',
#  '1',
#  '752\n2.819999933242798',
#  '18',
#  '1',
#  '1',
#  '747\n1.659999966621399',
#  '6',
#  '1',
#  '2',
#  '729\n0',
#  '5.5',
#  '3',
#  '1',
#  '726\n3.3399999141693115',
#  '21.5',
#  '2',
#  '1',
#  '722\n0',
#  '19',
#  '1',
#  '2',
#  '719\n1.3600000143051147',
#  '6',
#  '1',
#  '1',
#  '711\n0',
#  '8',
#  '1',
#  '1',
#  '708\n11.670000076293945',
#  '52',
#  '2',
#  '1',
#  ...]

# %%
client.command("""
SELECT
    pickup_ntaname,
    toHour(pickup_datetime) as pickup_hour,
    SUM(1) AS pickups
FROM trips
WHERE pickup_ntaname != ''
GROUP BY pickup_ntaname, pickup_hour
ORDER BY pickup_ntaname, pickup_hour""")
# Out:
# ['Airport',
#  '0',
#  '3509\nAirport',
#  '1',
#  '1184\nAirport',
#  '2',
#  '401\nAirport',
#  '3',
#  '152\nAirport',
#  '4',
#  '213\nAirport',
#  '5',
#  '955\nAirport',
#  '6',
#  '2161\nAirport',
#  '7',
#  '3013\nAirport',
#  '8',
#  '3601\nAirport',
#  '9',
#  '3792\nAirport',
#  '10',
#  '4546\nAirport',
#  '11',
#  '4659\nAirport',
#  '12',
#  '4621\nAirport',
#  '13',
#  '5348\nAirport',
#  '14',
#  '5889\nAirport',
#  '15',
#  '6505\nAirport',
#  '16',
#  '6119\nAirport',
#  '17',
#  '6341\nAirport',
#  '18',
#  '6173\nAirport',
#  '19',
#  '6329\nAirport',
#  '20',
#  '6271\nAirport',
#  '21',
#  '6649\nAirport',
#  '22',
#  '6356\nAirport',
#  '23',
#  '6016\nAllerton-Pelham Gardens',
#  '4',
#  '1\nAllerton-Pelham Gardens',
#  '6',
#  '1\nAllerton-Pelham Gardens',
#  '7',
#  '1\nAllerton-Pelham Gardens',
#  '9',
#  '5\nAllerton-Pelham Gardens',
#  '10',
#  '3\nAllerton-Pelham Gardens',
#  '15',
#  '1\nAllerton-Pelham Gardens',
#  '20',
#  '2\nAllerton-Pelham Gardens',
#  '23',
#  "1\nAnnadale-Huguenot-Prince\\'s Bay-Eltingville",
#  '23',
#  '1\nArden Heights',
#  '11',
#  '1\nAstoria',
#  '0',
#  '287\nAstoria',
#  '1',
#  '281\nAstoria',
#  '2',
#  '244\nAstoria',
#  '3',
#  '240\nAstoria',
#  '4',
#  '231\nAstoria',
#  '5',
#  '182\nAstoria',
#  '6',
#  '265\nAstoria',
#  '7',
#  '273\nAstoria',
#  '8',
#  '211\nAstoria',
#  '9',
#  '169\nAstoria',
#  '10',
#  '150\nAstoria',
#  '11',
#  '122\nAstoria',
#  '12',
#  '112\nAstoria',
#  '13',
#  '120\nAstoria',
#  '14',
#  '103\nAstoria',
#  '15',
#  '109\nAstoria',
#  '16',
#  '79\nAstoria',
#  '17',
#  '98\nAstoria',
#  '18',
#  '102\nAstoria',
#  '19',
#  '88\nAstoria',
#  '20',
#  '118\nAstoria',
#  '21',
#  '119\nAstoria',
#  '22',
#  '144\nAstoria',
#  '23',
#  '208\nAuburndale',
#  '0',
#  '1\nAuburndale',
#  '10',
#  '1\nAuburndale',
#  '12',
#  '1\nAuburndale',
#  '13',
#  '2\nAuburndale',
#  '15',
#  '1\nAuburndale',
#  '16',
#  '1\nAuburndale',
#  '18',
#  '1\nAuburndale',
#  '21',
#  '1\nAuburndale',
#  '22',
#  '1\nAuburndale',
#  '23',
#  '1\nBaisley Park',
#  '0',
#  '6\nBaisley Park',
#  '1',
#  '1\nBaisley Park',
#  '2',
#  '3\nBaisley Park',
#  '5',
#  '3\nBaisley Park',
#  '6',
#  '7\nBaisley Park',
#  '7',
#  '10\nBaisley Park',
#  '8',
#  '12\nBaisley Park',
#  '9',
#  '5\nBaisley Park',
#  '10',
#  '7\nBaisley Park',
#  '11',
#  '11\nBaisley Park',
#  '12',
#  '17\nBaisley Park',
#  '13',
#  '17\nBaisley Park',
#  '14',
#  '14\nBaisley Park',
#  '15',
#  '39\nBaisley Park',
#  '16',
#  '39\nBaisley Park',
#  '17',
#  '32\nBaisley Park',
#  '18',
#  '28\nBaisley Park',
#  '19',
#  '16\nBaisley Park',
#  '20',
#  '24\nBaisley Park',
#  '21',
#  '19\nBaisley Park',
#  '22',
#  '10\nBaisley Park',
#  '23',
#  '13\nBath Beach',
#  '0',
#  '1\nBath Beach',
#  '2',
#  '1\nBath Beach',
#  '3',
#  '1\nBath Beach',
#  '4',
#  '1\nBath Beach',
#  '5',
#  '1\nBath Beach',
#  '7',
#  '2\nBath Beach',
#  '9',
#  '2\nBath Beach',
#  '14',
#  '1\nBath Beach',
#  '15',
#  '3\nBath Beach',
#  '17',
#  '2\nBath Beach',
#  '18',
#  '1\nBath Beach',
#  '21',
#  '2\nBath Beach',
#  '22',
#  '1\nBattery Park City-Lower Manhattan',
#  '0',
#  '1762\nBattery Park City-Lower Manhattan',
#  '1',
#  '1047\nBattery Park City-Lower Manhattan',
#  '2',
#  '590\nBattery Park City-Lower Manhattan',
#  '3',
#  '338\nBattery Park City-Lower Manhattan',
#  '4',
#  '296\nBattery Park City-Lower Manhattan',
#  '5',
#  '511\nBattery Park City-Lower Manhattan',
#  '6',
#  '1206\nBattery Park City-Lower Manhattan',
#  '7',
#  '2072\nBattery Park City-Lower Manhattan',
#  '8',
#  '2791\nBattery Park City-Lower Manhattan',
#  '9',
#  '2664\nBattery Park City-Lower Manhattan',
#  '10',
#  '2528\nBattery Park City-Lower Manhattan',
#  '11',
#  '2916\nBattery Park City-Lower Manhattan',
#  '12',
#  '3195\nBattery Park City-Lower Manhattan',
#  '13',
#  '3375\nBattery Park City-Lower Manhattan',
#  '14',
#  '3498\nBattery Park City-Lower Manhattan',
#  '15',
#  '3238\nBattery Park City-Lower Manhattan',
#  '16',
#  '2895\nBattery Park City-Lower Manhattan',
#  '17',
#  '3408\nBattery Park City-Lower Manhattan',
#  '18',
#  '4004\nBattery Park City-Lower Manhattan',
#  '19',
#  '3991\nBattery Park City-Lower Manhattan',
#  '20',
#  '3869\nBattery Park City-Lower Manhattan',
#  '21',
#  '3662\nBattery Park City-Lower Manhattan',
#  '22',
#  '3050\nBattery Park City-Lower Manhattan',
#  '23',
#  '2310\nBay Ridge',
#  '0',
#  '11\nBay Ridge',
#  '1',
#  '11\nBay Ridge',
#  '2',
#  '8\nBay Ridge',
#  '3',
#  '11\nBay Ridge',
#  '4',
#  '3\nBay Ridge',
#  '5',
#  '2\nBay Ridge',
#  '6',
#  '5\nBay Ridge',
#  '7',
#  '2\nBay Ridge',
#  '8',
#  '3\nBay Ridge',
#  '9',
#  '1\nBay Ridge',
#  '10',
#  '4\nBay Ridge',
#  '11',
#  '3\nBay Ridge',
#  '12',
#  '3\nBay Ridge',
#  '13',
#  '2\nBay Ridge',
#  '14',
#  '3\nBay Ridge',
#  '15',
#  '1\nBay Ridge',
#  '16',
#  '1\nBay Ridge',
#  '17',
#  '1\nBay Ridge',
#  '18',
#  '1\nBay Ridge',
#  '19',
#  '5\nBay Ridge',
#  '20',
#  '5\nBay Ridge',
#  '21',
#  '6\nBay Ridge',
#  '22',
#  '13\nBay Ridge',
#  '23',
#  '9\nBayside-Bayside Hills',
#  '0',
#  '1\nBayside-Bayside Hills',
#  '2',
#  '2\nBayside-Bayside Hills',
#  '15',
#  '1\nBayside-Bayside Hills',
#  '18',
#  '3\nBedford',
#  '0',
#  '101\nBedford',
#  '1',
#  '103\nBedford',
#  '2',
#  '78\nBedford',
#  '3',
#  '42\nBedford',
#  '4',
#  '33\nBedford',
#  '5',
#  '24\nBedford',
#  '6',
#  '11\nBedford',
#  '7',
#  '10\nBedford',
#  '8',
#  '11\nBedford',
#  '9',
#  '10\nBedford',
#  '10',
#  '12\nBedford',
#  '11',
#  '7\nBedford',
#  '12',
#  '15\nBedford',
#  '13',
#  '10\nBedford',
#  '14',
#  '19\nBedford',
#  '15',
#  '12\nBedford',
#  '16',
#  '7\nBedford',
#  '17',
#  '13\nBedford',
#  '18',
#  '11\nBedford',
#  '19',
#  '31\nBedford',
#  '20',
#  '33\nBedford',
#  '21',
#  '43\nBedford',
#  '22',
#  '48\nBedford',
#  '23',
#  '97\nBedford Park-Fordham North',
#  '0',
#  '1\nBedford Park-Fordham North',
#  '1',
#  '1\nBedford Park-Fordham North',
#  '2',
#  '2\nBedford Park-Fordham North',
#  '3',
#  '3\nBedford Park-Fordham North',
#  '4',
#  '2\nBedford Park-Fordham North',
#  '6',
#  '1\nBedford Park-Fordham North',
#  '7',
#  '1\nBedford Park-Fordham North',
#  '11',
#  '1\nBedford Park-Fordham North',
#  '13',
#  '1\nBedford Park-Fordham North',
#  '14',
#  '1\nBedford Park-Fordham North',
#  '15',
#  '2\nBedford Park-Fordham North',
#  '16',
#  '1\nBedford Park-Fordham North',
#  '21',
#  '1\nBedford Park-Fordham North',
#  '22',
#  '1\nBellerose',
#  '0',
#  '3\nBellerose',
#  '7',
#  '1\nBellerose',
#  '8',
#  '1\nBellerose',
#  '9',
#  '1\nBellerose',
#  '12',
#  '1\nBellerose',
#  '15',
#  '3\nBellerose',
#  '16',
#  '2\nBellerose',
#  '18',
#  '1\nBellerose',
#  '19',
#  '1\nBellerose',
#  '20',
#  '2\nBelmont',
#  '7',
#  '1\nBelmont',
#  '8',
#  '1\nBelmont',
#  '9',
#  '1\nBelmont',
#  '10',
#  '1\nBelmont',
#  '11',
#  '1\nBelmont',
#  '14',
#  '2\nBelmont',
#  '15',
#  '1\nBelmont',
#  '21',
#  '1\nBelmont',
#  '23',
#  '1\nBensonhurst East',
#  '0',
#  '1\nBensonhurst East',
#  '1',
#  '1\nBensonhurst East',
#  '2',
#  '4\nBensonhurst East',
#  '3',
#  '2\nBensonhurst East',
#  '4',
#  '1\nBensonhurst East',
#  '5',
#  '1\nBensonhurst East',
#  '6',
#  '3\nBensonhurst East',
#  '7',
#  '2\nBensonhurst East',
#  '10',
#  '1\nBensonhurst East',
#  '13',
#  '1\nBensonhurst East',
#  '16',
#  '3\nBensonhurst East',
#  '18',
#  '1\nBensonhurst East',
#  '21',
#  '1\nBensonhurst East',
#  '23',
#  '1\nBensonhurst West',
#  '0',
#  '2\nBensonhurst West',
#  '1',
#  '1\nBensonhurst West',
#  '2',
#  '2\nBensonhurst West',
#  '3',
#  '3\nBensonhurst West',
#  '5',
#  '3\nBensonhurst West',
#  '6',
#  '3\nBensonhurst West',
#  '7',
#  '3\nBensonhurst West',
#  '9',
#  '1\nBensonhurst West',
#  '12',
#  '1\nBensonhurst West',
#  '14',
#  '2\nBensonhurst West',
#  '17',
#  '1\nBensonhurst West',
#  '18',
#  '1\nBensonhurst West',
#  '20',
#  '3\nBensonhurst West',
#  '21',
#  '3\nBensonhurst West',
#  '22',
#  '1\nBorough Park',
#  '0',
#  '3\nBorough Park',
#  '1',
#  '1\nBorough Park',
#  '2',
#  '1\nBorough Park',
#  '3',
#  '2\nBorough Park',
#  '4',
#  '1\nBorough Park',
#  '5',
#  '1\nBorough Park',
#  '7',
#  '1\nBorough Park',
#  '9',
#  '1\nBorough Park',
#  '10',
#  '3\nBorough Park',
#  '11',
#  '1\nBorough Park',
#  '12',
#  '1\nBorough Park',
#  '13',
#  '1\nBorough Park',
#  '14',
#  '1\nBorough Park',
#  '15',
#  '2\nBorough Park',
#  '16',
#  '3\nBorough Park',
#  '17',
#  '3\nBorough Park',
#  '18',
#  '3\nBorough Park',
#  '21',
#  '2\nBreezy Point-Belle Harbor-Rockaway Park-Broad Channel',
#  '0',
#  '1\nBreezy Point-Belle Harbor-Rockaway Park-Broad Channel',
#  '1',
#  '1\nBreezy Point-Belle Harbor-Rockaway Park-Broad Channel',
#  '5',
#  '1\nBreezy Point-Belle Harbor-Rockaway Park-Broad Channel',
#  '22',
#  '1\nBriarwood-Jamaica Hills',
#  '0',
#  '5\nBriarwood-Jamaica Hills',
#  '1',
#  '7\nBriarwood-Jamaica Hills',
#  '2',
#  '3\nBriarwood-Jamaica Hills',
#  '3',
#  '3\nBriarwood-Jamaica Hills',
#  '4',
#  '3\nBriarwood-Jamaica Hills',
#  '5',
#  '8\nBriarwood-Jamaica Hills',
#  '6',
#  '12\nBriarwood-Jamaica Hills',
#  '7',
#  '11\nBriarwood-Jamaica Hills',
#  '8',
#  '9\nBriarwood-Jamaica Hills',
#  '9',
#  '5\nBriarwood-Jamaica Hills',
#  '10',
#  '4\nBriarwood-Jamaica Hills',
#  '11',
#  '12\nBriarwood-Jamaica Hills',
#  '12',
#  '8\nBriarwood-Jamaica Hills',
#  '13',
#  '8\nBriarwood-Jamaica Hills',
#  '14',
#  '11\nBriarwood-Jamaica Hills',
#  '15',
#  '8\nBriarwood-Jamaica Hills',
#  '16',
#  '5\nBriarwood-Jamaica Hills',
#  '17',
#  '16\nBriarwood-Jamaica Hills',
#  '18',
#  '9\nBriarwood-Jamaica Hills',
#  '19',
#  '6\nBriarwood-Jamaica Hills',
#  '20',
#  '9\nBriarwood-Jamaica Hills',
#  '21',
#  '3\nBriarwood-Jamaica Hills',
#  '22',
#  '9\nBriarwood-Jamaica Hills',
#  '23',
#  '10\nBrighton Beach',
#  '0',
#  '1\nBrighton Beach',
#  '5',
#  '1\nBrighton Beach',
#  '6',
#  '1\nBrighton Beach',
#  '10',
#  '1\nBrighton Beach',
#  '11',
#  '1\nBrighton Beach',
#  '12',
#  '2\nBrighton Beach',
#  '14',
#  '2\nBrighton Beach',
#  '15',
#  '1\nBrighton Beach',
#  '16',
#  '4\nBrighton Beach',
#  '17',
#  '1\nBrighton Beach',
#  '18',
#  '2\nBrighton Beach',
#  '19',
#  '2\nBrighton Beach',
#  '20',
#  '1\nBrighton Beach',
#  '22',
#  '1\nBrighton Beach',
#  '23',
#  '2\nBronxdale',
#  '1',
#  '1\nBronxdale',
#  '5',
#  '3\nBronxdale',
#  '11',
#  '1\nBronxdale',
#  '13',
#  '1\nBronxdale',
#  '16',
#  '1\nBrooklyn Heights-Cobble Hill',
#  '0',
#  '102\nBrooklyn Heights-Cobble Hill',
#  '1',
#  '62\nBrooklyn Heights-Cobble Hill',
#  '2',
#  '35\nBrooklyn Heights-Cobble Hill',
#  '3',
#  '21\nBrooklyn Heights-Cobble Hill',
#  '4',
#  '17\nBrooklyn Heights-Cobble Hill',
#  '5',
#  '51\nBrooklyn Heights-Cobble Hill',
#  '6',
#  '159\nBrooklyn Heights-Cobble Hill',
#  '7',
#  '200\nBrooklyn Heights-Cobble Hill',
#  '8',
#  '161\nBrooklyn Heights-Cobble Hill',
#  '9',
#  '125\nBrooklyn Heights-Cobble Hill',
#  '10',
#  '85\nBrooklyn Heights-Cobble Hill',
#  '11',
#  '61\nBrooklyn Heights-Cobble Hill',
#  '12',
#  '110\nBrooklyn Heights-Cobble Hill',
#  '13',
#  '79\nBrooklyn Heights-Cobble Hill',
#  '14',
#  '92\nBrooklyn Heights-Cobble Hill',
#  '15',
#  '74\nBrooklyn Heights-Cobble Hill',
#  '16',
#  '63\nBrooklyn Heights-Cobble Hill',
#  '17',
#  '77\nBrooklyn Heights-Cobble Hill',
#  '18',
#  '88\nBrooklyn Heights-Cobble Hill',
#  '19',
#  '94\nBrooklyn Heights-Cobble Hill',
#  '20',
#  '97\nBrooklyn Heights-Cobble Hill',
#  '21',
#  '108\nBrooklyn Heights-Cobble Hill',
#  '22',
#  '135\nBrooklyn Heights-Cobble Hill',
#  '23',
#  '111\nBrownsville',
#  '0',
#  '5\nBrownsville',
#  '1',
#  '3\nBrownsville',
#  '2',
#  '1\nBrownsville',
#  '3',
#  '3\nBrownsville',
#  '4',
#  '2\nBrownsville',
#  '7',
#  '4\nBrownsville',
#  '9',
#  '1\nBrownsville',
#  '11',
#  '1\nBrownsville',
#  '13',
#  '1\nBrownsville',
#  '15',
#  '1\nBrownsville',
#  '16',
#  '2\nBrownsville',
#  '17',
#  '1\nBrownsville',
#  '20',
#  '2\nBrownsville',
#  '21',
#  '1\nBrownsville',
#  '22',
#  '4\nBrownsville',
#  '23',
#  '1\nBushwick North',
#  '0',
#  '76\nBushwick North',
#  '1',
#  '95\nBushwick North',
#  '2',
#  '74\nBushwick North',
#  '3',
#  '69\nBushwick North',
#  '4',
#  '54\nBushwick North',
#  '5',
#  '11\nBushwick North',
#  '6',
#  '5\nBushwick North',
#  '7',
#  '2\nBushwick North',
#  '8',
#  '2\nBushwick North',
#  '9',
#  '4\nBushwick North',
#  '10',
#  '3\nBushwick North',
#  '11',
#  '4\nBushwick North',
#  '12',
#  '2\nBushwick North',
#  '13',
#  '4\nBushwick North',
#  '14',
#  '4\nBushwick North',
#  '15',
#  '3\nBushwick North',
#  '16',
#  '2\nBushwick North',
#  '17',
#  '4\nBushwick North',
#  '18',
#  '6\nBushwick North',
#  '19',
#  '6\nBushwick North',
#  '20',
#  '15\nBushwick North',
#  '21',
#  '21\nBushwick North',
#  '22',
#  '24\nBushwick North',
#  '23',
#  '44\nBushwick South',
#  '0',
#  '160\nBushwick South',
#  '1',
#  '163\nBushwick South',
#  '2',
#  '155\nBushwick South',
#  '3',
#  '89\nBushwick South',
#  '4',
#  '86\nBushwick South',
#  '5',
#  '36\nBushwick South',
#  '6',
#  '11\nBushwick South',
#  '7',
#  '8\nBushwick South',
#  '8',
#  '2\nBushwick South',
#  '9',
#  '3\nBushwick South',
#  '10',
#  '3\nBushwick South',
#  '11',
#  '7\nBushwick South',
#  '12',
#  '7\nBushwick South',
#  '13',
#  '14\nBushwick South',
#  '14',
#  '13\nBushwick South',
#  '15',
#  '9\nBushwick South',
#  '16',
#  '4\nBushwick South',
#  '17',
#  '10\nBushwick South',
#  '18',
#  '17\nBushwick South',
#  '19',
#  '32\nBushwick South',
#  '20',
#  '35\nBushwick South',
#  '21',
#  '43\nBushwick South',
#  '22',
#  '72\nBushwick South',
#  '23',
#  '114\nCambria Heights',
#  '6',
#  '1\nCambria Heights',
#  '14',
#  '2\nCambria Heights',
#  '23',
#  '1\nCanarsie',
#  '0',
#  '2\nCanarsie',
#  '2',
#  '3\nCanarsie',
#  '3',
#  '2\nCanarsie',
#  '5',
#  '1\nCanarsie',
#  '8',
#  '1\nCanarsie',
#  '9',
#  '1\nCanarsie',
#  '10',
#  '2\nCanarsie',
#  '12',
#  '3\nCanarsie',
#  '13',
#  '2\nCanarsie',
#  '14',
#  '2\nCanarsie',
#  '16',
#  '1\nCanarsie',
#  '17',
#  '2\nCanarsie',
#  '18',
#  '2\nCanarsie',
#  '19',
#  '2\nCanarsie',
#  '20',
#  '1\nCanarsie',
#  '21',
#  '5\nCanarsie',
#  '22',
#  '2\nCanarsie',
#  '23',
#  '2\nCarroll Gardens-Columbia Street-Red Hook',
#  '0',
#  '131\nCarroll Gardens-Columbia Street-Red Hook',
#  '1',
#  '83\nCarroll Gardens-Columbia Street-Red Hook',
#  '2',
#  '54\nCarroll Gardens-Columbia Street-Red Hook',
#  '3',
#  '35\nCarroll Gardens-Columbia Street-Red Hook',
#  '4',
#  '29\nCarroll Gardens-Columbia Street-Red Hook',
#  '5',
#  '64\nCarroll Gardens-Columbia Street-Red Hook',
#  '6',
#  '166\nCarroll Gardens-Columbia Street-Red Hook',
#  '7',
#  '253\nCarroll Gardens-Columbia Street-Red Hook',
#  '8',
#  '320\nCarroll Gardens-Columbia Street-Red Hook',
#  '9',
#  '203\nCarroll Gardens-Columbia Street-Red Hook',
#  '10',
#  '131\nCarroll Gardens-Columbia Street-Red Hook',
#  '11',
#  '97\nCarroll Gardens-Columbia Street-Red Hook',
#  '12',
#  '102\nCarroll Gardens-Columbia Street-Red Hook',
#  '13',
#  '79\nCarroll Gardens-Columbia Street-Red Hook',
#  '14',
#  '92\nCarroll Gardens-Columbia Street-Red Hook',
#  '15',
#  '70\nCarroll Gardens-Columbia Street-Red Hook',
#  '16',
#  '52\nCarroll Gardens-Columbia Street-Red Hook',
#  '17',
#  '81\nCarroll Gardens-Columbia Street-Red Hook',
#  '18',
#  '111\nCarroll Gardens-Columbia Street-Red Hook',
#  '19',
#  '104\nCarroll Gardens-Columbia Street-Red Hook',
#  '20',
#  '97\nCarroll Gardens-Columbia Street-Red Hook',
#  '21',
#  '125\nCarroll Gardens-Columbia Street-Red Hook',
#  '22',
#  '170\nCarroll Gardens-Columbia Street-Red Hook',
#  '23',
#  '170\nCentral Harlem North-Polo Grounds',
#  '0',
#  '137\nCentral Harlem North-Polo Grounds',
#  '1',
#  '103\nCentral Harlem North-Polo Grounds',
#  '2',
#  '76\nCentral Harlem North-Polo Grounds',
#  '3',
#  '80\nCentral Harlem North-Polo Grounds',
#  '4',
#  '62\nCentral Harlem North-Polo Grounds',
#  '5',
#  '74\nCentral Harlem North-Polo Grounds',
#  '6',
#  '157\nCentral Harlem North-Polo Grounds',
#  '7',
#  '211\nCentral Harlem North-Polo Grounds',
#  '8',
#  '180\nCentral Harlem North-Polo Grounds',
#  '9',
#  '115\nCentral Harlem North-Polo Grounds',
#  '10',
#  '101\nCentral Harlem North-Polo Grounds',
#  '11',
#  '81\nCentral Harlem North-Polo Grounds',
#  '12',
#  '87\nCentral Harlem North-Polo Grounds',
#  '13',
#  '99\nCentral Harlem North-Polo Grounds',
#  '14',
#  '93\nCentral Harlem North-Polo Grounds',
#  '15',
#  '87\nCentral Harlem North-Polo Grounds',
#  '16',
#  '97\nCentral Harlem North-Polo Grounds',
#  '17',
#  '149\nCentral Harlem North-Polo Grounds',
#  '18',
#  '103\nCentral Harlem North-Polo Grounds',
#  '19',
#  '96\nCentral Harlem North-Polo Grounds',
#  '20',
#  '117\nCentral Harlem North-Polo Grounds',
#  '21',
#  '107\nCentral Harlem North-Polo Grounds',
#  '22',
#  '122\nCentral Harlem North-Polo Grounds',
#  '23',
#  '125\nCentral Harlem South',
#  '0',
#  '234\nCentral Harlem South',
#  '1',
#  '191\nCentral Harlem South',
#  '2',
#  '146\nCentral Harlem South',
#  '3',
#  '110\nCentral Harlem South',
#  '4',
#  '87\nCentral Harlem South',
#  '5',
#  '140\nCentral Harlem South',
#  '6',
#  '241\nCentral Harlem South',
#  '7',
#  '371\nCentral Harlem South',
#  '8',
#  '340\nCentral Harlem South',
#  '9',
#  '269\nCentral Harlem South',
#  '10',
#  '232\nCentral Harlem South',
#  '11',
#  '211\nCentral Harlem South',
#  '12',
#  '239\nCentral Harlem South',
#  '13',
#  '257\nCentral Harlem South',
#  '14',
#  '256\nCentral Harlem South',
#  '15',
#  '215\nCentral Harlem South',
#  '16',
#  '211\nCentral Harlem South',
#  '17',
#  '300\nCentral Harlem South',
#  '18',
#  '282\nCentral Harlem South',
#  '19',
#  '253\nCentral Harlem South',
#  '20',
#  '277\nCentral Harlem South',
#  '21',
#  '263\nCentral Harlem South',
#  '22',
#  '269\nCentral Harlem South',
#  '23',
#  '276\nChinatown',
#  '0',
#  '3159\nChinatown',
#  '1',
#  '3282\nChinatown',
#  '2',
#  '3090\nChinatown',
#  '3',
#  '2425\nChinatown',
#  '4',
#  '1271\nChinatown',
#  '5',
#  '454\nChinatown',
#  '6',
#  '449\nChinatown',
#  '7',
#  '535\nChinatown',
#  '8',
#  '709\nChinatown',
#  '9',
#  '901\nChinatown',
#  '10',
#  '855\nChinatown',
#  '11',
#  ...]

# %%
client.command("""
SELECT
    pickup_datetime,
    dropoff_datetime,
    total_amount,
    pickup_nyct2010_gid,
    dropoff_nyct2010_gid,
    CASE
        WHEN dropoff_nyct2010_gid = 138 THEN 'LGA'
        WHEN dropoff_nyct2010_gid = 132 THEN 'JFK'
    END AS airport_code,
    EXTRACT(YEAR FROM pickup_datetime) AS year,
    EXTRACT(DAY FROM pickup_datetime) AS day,
    EXTRACT(HOUR FROM pickup_datetime) AS hour
FROM trips
WHERE dropoff_nyct2010_gid IN (132, 138)
ORDER BY pickup_datetime""")
# Out:
# ['2015-07-01 00:04:14',
#  '2015-07-01 00:15:29',
#  '13.3',
#  '-34',
#  '132',
#  'JFK',
#  '2015',
#  '1',
#  '0\n2015-07-01 00:09:42',
#  '2015-07-01 00:12:55',
#  '6.8',
#  '50',
#  '138',
#  'LGA',
#  '2015',
#  '1',
#  '0\n2015-07-01 00:23:04',
#  '2015-07-01 00:24:39',
#  '4.8',
#  '-125',
#  '132',
#  'JFK',
#  '2015',
#  '1',
#  '0\n2015-07-01 00:27:51',
#  '2015-07-01 00:39:02',
#  '14.72',
#  '-101',
#  '138',
#  'LGA',
#  '2015',
#  '1',
#  '0\n2015-07-01 00:32:03',
#  '2015-07-01 00:55:39',
#  '39.34',
#  '48',
#  '138',
#  'LGA',
#  '2015',
#  '1',
#  '0\n2015-07-01 00:34:12',
#  '2015-07-01 00:40:48',
#  '9.95',
#  '-93',
#  '132',
#  'JFK',
#  '2015',
#  '1',
#  '0\n2015-07-01 00:38:26',
#  '2015-07-01 00:49:00',
#  '13.3',
#  '-11',
#  '138',
#  'LGA',
#  '2015',
#  '1',
#  '0\n2015-07-01 00:41:48',
#  '2015-07-01 00:44:45',
#  '6.3',
#  '-94',
#  '132',
#  'JFK',
#  '2015',
#  '1',
#  '0\n2015-07-01 01:06:18',
#  '2015-07-01 01:14:43',
#  '11.76',
#  '37',
#  '132',
#  'JFK',
#  '2015',
#  '1',
#  '1\n2015-07-01 01:07:34',
#  '2015-07-01 01:30:56',
#  '23.8',
#  '42',
#  '138',
#  'LGA',
#  '2015',
#  '1',
#  '1\n2015-07-01 01:11:41',
#  '2015-07-01 01:18:23',
#  '10.56',
#  '14',
#  '132',
#  'JFK',
#  '2015',
#  '1',
#  '1\n2015-07-01 01:18:13',
#  '2015-07-01 01:27:49',
#  '11.3',
#  '93',
#  '132',
#  'JFK',
#  '2015',
#  '1',
#  '1\n2015-07-01 01:20:24',
#  '2015-07-01 01:28:09',
#  '8.8',
#  '79',
#  '132',
#  'JFK',
#  '2015',
#  '1',
#  '1\n2015-07-01 01:44:03',
#  '2015-07-01 02:09:52',
#  '69.34',
#  '8',
#  '138',
#  'LGA',
#  '2015',
#  '1',
#  '1\n2015-07-01 01:47:32',
#  '2015-07-01 01:56:00',
#  '12.25',
#  '37',
#  '132',
#  'JFK',
#  '2015',
#  '1',
#  '1\n2015-07-01 01:54:17',
#  '2015-07-01 02:03:16',
#  '11.75',
#  '4',
#  '132',
#  'JFK',
#  '2015',
#  '1',
#  '1\n2015-07-01 01:58:07',
#  '2015-07-01 02:05:27',
#  '9.8',
#  '75',
#  '132',
#  'JFK',
#  '2015',
#  '1',
#  '1\n2015-07-01 02:08:04',
#  '2015-07-01 02:18:01',
#  '12.96',
#  '-114',
#  '138',
#  'LGA',
#  '2015',
#  '1',
#  '2\n2015-07-01 02:10:00',
#  '2015-07-01 02:14:56',
#  '9.96',
#  '-31',
#  '132',
#  'JFK',
#  '2015',
#  '1',
#  '2\n2015-07-01 02:27:05',
#  '2015-07-01 02:31:24',
#  '6.3',
#  '21',
#  '138',
#  'LGA',
#  '2015',
#  '1',
#  '2\n2015-07-01 02:32:05',
#  '2015-07-01 02:34:31',
#  '5.8',
#  '-122',
#  '132',
#  'JFK',
#  '2015',
#  '1',
#  '2\n2015-07-01 02:35:59',
#  '2015-07-01 02:38:22',
#  '5.8',
#  '-124',
#  '132',
#  'JFK',
#  '2015',
#  '1',
#  '2\n2015-07-01 02:41:52',
#  '2015-07-01 02:46:50',
#  '8.15',
#  '-116',
#  '138',
#  'LGA',
#  '2015',
#  '1',
#  '2\n2015-07-01 02:42:21',
#  '2015-07-01 02:45:55',
#  '5.8',
#  '-18',
#  '132',
#  'JFK',
#  '2015',
#  '1',
#  

#  '132',
#  'JFK',
#  '2015',
#  '1',
#  '13\n2015-07-01 13:09:14',
#  '2015-07-01 13:22:31',
#  '11',
#  '-31',
#  '132',
#  'JFK',
#  '2015',
#  '1',
#  ...]

# %%
# Create a sample database and table
client.command("CREATE DATABASE IF NOT EXISTS demo")
client.command("""
CREATE TABLE IF NOT EXISTS demo.sales (
    id UInt32,
    region String,
    amount Float64
) ENGINE = MergeTree()
ORDER BY id
""")
print("Table 'demo.sales' created successfully.")
# Out:
# Table 'demo.sales' created successfully.

# %%
# Insert sample data into the table
data = [(1, 'EU', 1200.0), (2, 'ASIA', 800.0), (3, 'EU', 500.0), (4, 'NA', 2000.0)]
client.insert('demo.sales', data, column_names=['id', 'region', 'amount'])
print("Inserted sample rows into demo.sales.")
# Out:
# Inserted sample rows into demo.sales.

# %%
# Run a query to retrieve all data
result = client.query_df("SELECT * FROM demo.sales")
print(result)
# Out:
#    id region  amount
# 0   1     EU  1200.0
# 1   2   ASIA   800.0
# 2   3     EU   500.0
# 3   4     NA  2000.0

# %%
# Aggregation query - total sales by region
agg_result = client.query_df("SELECT region, SUM(amount) AS total_sales FROM demo.sales GROUP BY region ORDER BY total_sales DESC")
print(agg_result)
# Out:
#   region  total_sales
# 0     NA       2000.0
# 1     EU       1700.0
# 2   ASIA        800.0

# %%
# Filtering query - show regions with total sales > 1000
filter_result = client.query_df("SELECT region, SUM(amount) AS total_sales FROM demo.sales GROUP BY region HAVING total_sales > 1000")
print(filter_result)
# Out:
#   region  total_sales
# 0     NA       2000.0
# 1     EU       1700.0

# %%
# Clean up
client.command("DROP TABLE IF EXISTS demo.sales")
client.command("DROP DATABASE IF EXISTS demo")
print("Cleaned up demo database.")
# Out:
# Cleaned up demo database.

# %%
# Aggregating using built-in functions
func_df = client.query_df("""
                          SELECT region,
                                 COUNT()     AS transactions,
                                 AVG(amount) AS avg_sale,
                                 MAX(amount) AS max_sale,
                                 MIN(amount) AS min_sale
                          FROM demo.sales
                          GROUP BY region
                          ORDER BY avg_sale DESC
                          """)
print(func_df)
# Out:
#   region  transactions  avg_sale  max_sale  min_sale
# 0     NA             1    2000.0    2000.0    2000.0
# 1     EU             2     850.0    1200.0     500.0
# 2   ASIA             1     800.0     800.0     800.0

# %%
# Query using string functions
string_df = client.query_df("""
                            SELECT region, length(region) AS len, upper(region) AS upper_region
                            FROM demo.sales
                            ORDER BY len DESC
                            """)
print(string_df)
# Out:
#   region  len upper_region
# 0   ASIA    4         ASIA
# 1     EU    2           EU
# 2     EU    2           EU
# 3     NA    2           NA

# %%
# Demonstrate join operation
client.command("""
               CREATE TABLE IF NOT EXISTS demo.regions_info
               (
                   region
                   String,
                   continent
                   String
               ) ENGINE = MergeTree
               (
               )
                   ORDER BY region
               """)
client.insert('demo.regions_info', [('EU', 'Europe'), ('ASIA', 'Asia'), ('NA', 'North America')],
              column_names=['region', 'continent'])

join_df = client.query_df("""
                          SELECT s.region, r.continent, SUM(s.amount) AS total
                          FROM demo.sales s
                                   JOIN demo.regions_info r ON s.region = r.region
                          GROUP BY s.region, r.continent
                          ORDER BY total DESC
                          """)
print(join_df)
# Out:
#   region      continent   total
# 0     NA  North America  2000.0
# 1     EU         Europe  1700.0
# 2   ASIA           Asia   800.0
